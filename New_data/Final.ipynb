# %%
import pandas as pd

# %%
df = pd.read_excel('Book.xlsx')

# %%
df
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 0           GSEB           63         GUJCET           0            49
# 1           GSEB           74            JEE          80             0
# 2           CBSE           80            JEE          84             0
# 3           CBSE           71         GUJCET           0            56
# 4           GSEB           55         GUJCET           0            24
# ...          ...          ...            ...         ...           ...
# 4375        CBSE           54            JEE          62             0
# 4376        GSEB           55         GUJCET           0            51
# 4377        GSEB           54            JEE          53             0
# 4378        CBSE           54         GUJCET           0            49
# 4379        CBSE           53            JEE          51             0
#
#                           College/University  \
# 0                 SAL COLLEGE OF ENGINEERING
# ...

# %%
import numpy as np

# %%
df['XII60'] =df['XIIth score']*0.6

# %%
df
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 0           GSEB           63         GUJCET           0            49
# 1           GSEB           74            JEE          80             0
# 2           CBSE           80            JEE          84             0
# 3           CBSE           71         GUJCET           0            56
# 4           GSEB           55         GUJCET           0            24
# ...          ...          ...            ...         ...           ...
# 4375        CBSE           54            JEE          62             0
# 4376        GSEB           55         GUJCET           0            51
# 4377        GSEB           54            JEE          53             0
# 4378        CBSE           54         GUJCET           0            49
# 4379        CBSE           53            JEE          51             0
#
#                           College/University  \
# 0                 SAL COLLEGE OF ENGINEERING
# ...

# %%
df['GUJCET 40%'] =df['GUJCET Score']*0.4

# %%
df
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 0           GSEB           63         GUJCET           0            49
# 1           GSEB           74            JEE          80             0
# 2           CBSE           80            JEE          84             0
# 3           CBSE           71         GUJCET           0            56
# 4           GSEB           55         GUJCET           0            24
# ...          ...          ...            ...         ...           ...
# 4375        CBSE           54            JEE          62             0
# 4376        GSEB           55         GUJCET           0            51
# 4377        GSEB           54            JEE          53             0
# 4378        CBSE           54         GUJCET           0            49
# 4379        CBSE           53            JEE          51             0
#
#                           College/University  \
# 0                 SAL COLLEGE OF ENGINEERING
# ...

# %%
df['JEE 40%'] =df['JEE Score ']*0.4

# %%
df
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 0           GSEB           63         GUJCET           0            49
# 1           GSEB           74            JEE          80             0
# 2           CBSE           80            JEE          84             0
# 3           CBSE           71         GUJCET           0            56
# 4           GSEB           55         GUJCET           0            24
# ...          ...          ...            ...         ...           ...
# 4375        CBSE           54            JEE          62             0
# 4376        GSEB           55         GUJCET           0            51
# 4377        GSEB           54            JEE          53             0
# 4378        CBSE           54         GUJCET           0            49
# 4379        CBSE           53            JEE          51             0
#
#                           College/University  \
# 0                 SAL COLLEGE OF ENGINEERING
# ...

# %%
df["Final_G"] = df["XII60"] + df["GUJCET 40%"]

# %%
df
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 0           GSEB           63         GUJCET           0            49
# 1           GSEB           74            JEE          80             0
# 2           CBSE           80            JEE          84             0
# 3           CBSE           71         GUJCET           0            56
# 4           GSEB           55         GUJCET           0            24
# ...          ...          ...            ...         ...           ...
# 4375        CBSE           54            JEE          62             0
# 4376        GSEB           55         GUJCET           0            51
# 4377        GSEB           54            JEE          53             0
# 4378        CBSE           54         GUJCET           0            49
# 4379        CBSE           53            JEE          51             0
#
#                           College/University  \
# 0                 SAL COLLEGE OF ENGINEERING
# ...

# %%
df["Final_J"] = df["XII60"] + df["JEE 40%"]

# %%
df
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 0           GSEB           63         GUJCET           0            49
# 1           GSEB           74            JEE          80             0
# 2           CBSE           80            JEE          84             0
# 3           CBSE           71         GUJCET           0            56
# 4           GSEB           55         GUJCET           0            24
# ...          ...          ...            ...         ...           ...
# 4375        CBSE           54            JEE          62             0
# 4376        GSEB           55         GUJCET           0            51
# 4377        GSEB           54            JEE          53             0
# 4378        CBSE           54         GUJCET           0            49
# 4379        CBSE           53            JEE          51             0
#
#                           College/University  \
# 0                 SAL COLLEGE OF ENGINEERING
# ...

# %%
df.to_excel('Final.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     319             try:
# --> 320                 self._store_workbook()
#     321             except IOError as e:
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     637         except IOError as e:
# --> 638             raise e
#     639
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     634         try:
# --> 635             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
#     636                                 allowZip64=self.allow_zip64)
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1250                 try:
# -> 1251                     self.fp = io.open(file, filemode)
# ...

# %%
import pandas as pd
df1 = pd.read_excel("Final.xlsx")

# %%
df1
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 0           GSEB           63         GUJCET           0            49
# 1           GSEB           74            JEE          80             0
# 2           CBSE           80            JEE          84             0
# 3           CBSE           71         GUJCET           0            56
# 4           GSEB           55         GUJCET           0            24
# ...          ...          ...            ...         ...           ...
# 4375        CBSE           54            JEE          62             0
# 4376        GSEB           55         GUJCET           0            51
# 4377        GSEB           54            JEE          53             0
# 4378        CBSE           54         GUJCET           0            49
# 4379        CBSE           53            JEE          51             0
#
#                           College/University  \
# 0                 SAL COLLEGE OF ENGINEERING
# ...

# %%
twelve_board = (input('Enter your 12th Board: '))
# Out:
# Enter your 12th Board: GSEB

# %%
twelve_marks = int(input('Enter your 12th score: '))*0.6
# Out:
# Enter your 12th score: 75

# %%
twelve_marks
# Out:
# 45.0

# %%
given_entrance = (input('Enter your entrance given: '))
# Out:
# Enter your entrance given: JEE

# %%
GUJCET_marks = int(input('Enter your GUJCET score: '))*0.4
# Out:
# Enter your GUJCET score: 0

# %%
GUJCET_marks
# Out:
# 0.0

# %%
Final_GM= twelve_marks + GUJCET_marks

# %%
Final_GM
# Out:
# 45.0

# %%
enter_category = (input('Enter your Category: '))
# Out:
# Enter your Category: General

# %%
choose_field = (input('Enter your choice of field: '))
# Out:
# Enter your choice of field: Information Technology

# %%
df2 = df1[(df1["XIIth Board"] == twelve_board) & (df1["Entrance given"] == given_entrance)]

# %%
df2
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 1           GSEB           74            JEE          80             0
# 5           GSEB           69            JEE          57             0
# 9           GSEB           69            JEE          57             0
# 13          GSEB           69            JEE          57             0
# 17          GSEB           69            JEE          57             0
# ...          ...          ...            ...         ...           ...
# 4361        GSEB           84            JEE          81             0
# 4365        GSEB           75            JEE          77             0
# 4369        GSEB           67            JEE          63             0
# 4373        GSEB           58            JEE          59             0
# 4377        GSEB           54            JEE          53             0
#
#                           College/University  \
# 1                 SAL COLLEGE OF ENGINEERING
# ...

# %%
df2 = df2[(df2["Field"] == choose_field) & (df2["Final_J"] <= Final_GM)]

# %%
df2
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 305         GSEB           43            JEE          41             0
# 309         GSEB           43            JEE          41             0
# 313         GSEB           43            JEE          41             0
# 317         GSEB           43            JEE          41             0
# 1641        GSEB           44            JEE          15             0
# 1645        GSEB           39            JEE          30             0
# 1649        GSEB           39            JEE          30             0
# 1653        GSEB           39            JEE          30             0
# 1657        GSEB           39            JEE          30             0
# 1741        GSEB           52            JEE          34             0
# 1745        GSEB           41            JEE          34             0
# 1749        GSEB           41            JEE          34             0
# ...

# %%
df2 = df2[(df2["Category"] == enter_category)]

# %%
df2
# Out:
#      XIIth Board  XIIth score Entrance given  JEE Score   GUJCET Score  \
# 1641        GSEB           44            JEE          15             0
# 1741        GSEB           52            JEE          34             0
# 1901        GSEB           52            JEE          34             0
#
#                                      College/University  \
# 1641  TATVA INSTITUTE OF TECHNOLOGICAL STUDIES - [TITS]
# 1741                  VADODARA INSTITUTE OF ENGINEERING
# 1901                VEERAYATAN INSTITUTE OF ENGINEERING
#
#                        Field Category  XII60  GUJCET 40%  JEE 40%  Final_G  \
# 1641  Information Technology  General   26.4         0.0      6.0     26.4
# 1741  Information Technology  General   31.2         0.0     13.6     31.2
# 1901  Information Technology  General   31.2         0.0     13.6     31.2
#
#       Final_J
# 1641     32.4
# 1741     44.8
# 1901     44.8

# %%
df = df2['College/University']

# %%
df
# Out:
# 1641    TATVA INSTITUTE OF TECHNOLOGICAL STUDIES - [TITS]
# 1741                    VADODARA INSTITUTE OF ENGINEERING
# 1901                  VEERAYATAN INSTITUTE OF ENGINEERING
# Name: College/University, dtype: object

# %%
for i in df:
    print(i)
# Out:
# TATVA INSTITUTE OF TECHNOLOGICAL STUDIES - [TITS]
# VADODARA INSTITUTE OF ENGINEERING
# VEERAYATAN INSTITUTE OF ENGINEERING
